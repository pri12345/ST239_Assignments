# %%
## Imports and loading DFs

import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, date, timedelta
import numpy as np
import seaborn as sns
import scipy.stats as stats
from pathlib import Path

BASE_DIR = Path(r"C:/Users/prida/Desktop/ST238 Project/assignment 3")  # paste dir to folder w/ datasets here
d_pricing_path = BASE_DIR / "platform_device_pricing_proposals.csv"
viewers_path = BASE_DIR / "viewers_ST238.csv"
genre_path = BASE_DIR / "genre_metadata.csv"

pricing_df = pd.read_csv(d_pricing_path)
viewers_df = pd.read_csv(viewers_path)
genre_df = pd.read_csv(genre_path)

# %% [markdown]
# # First quick look @ datasets

# %% [markdown]
# ### Viewer Behaviour (first look)

# %% [markdown]
# ### Genre Metadata (first look)

# %% [markdown]
# ### Platform Pricing (first look)

# %% [markdown]
# # Exploration and identification of variables of interest

# %% [markdown]
# ### Viewer Behaviour (E & I)

# %% [markdown]
# ### Genre Metadata (E & I)

# %% [markdown]
# ### Platform Pricing (E & I)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Viewer Behaviour (Cleaning)

# %% [markdown]
# ### Genre Metadata (Cleaning)

# %% [markdown]
# ### Platform Pricing (Cleaning)

# %% [markdown]
# # Hypothesis and Testing

# %% [markdown]
# ### Viewer Behaviour (H & T)

# %% [markdown]
# ### Genre Metadata (H & T)

# %% [markdown]
# ### Platform Pricing (H & T)
